# %%
import cv2
import matplotlib.pyplot as plt

# img = cv2.imread('/content/drive/MyDrive/images/apple_1.jpg',0)
# hist1 = cv2.calcHist([img],[0],None,[256],[0,256])
# img_2 = cv2.equalizeHist(img)
# hist2 = cv2.calcHist([img_2],[0],None,[256],[0,256])
# plt.subplot(221),plt.imshow(img);
# plt.subplot(222),plt.plot(hist1);
# plt.subplot(223),plt.imshow(img_2);
# plt.subplot(224),plt.plot(hist2);

# import Opencv
import cv2
import glob
import os
  
# import Numpy
import numpy as np
from google.colab.patches import cv2_imshow
path=glob.glob('/content/drive/MyDrive/images/gamma_test_new/*')
for i in path:
  img = cv2.imread(i,1)
  head_tail = os.path.split(i)
  # img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  R,G,B=cv2.split(img)
  output_r=cv2.equalizeHist(R)
  output_g=cv2.equalizeHist(G)
  output_b=cv2.equalizeHist(B)
  output_1=cv2.merge((output_r,output_g,output_b))
  # output_1=cv2.equalizeHist(img)
  clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
  output2_r=clahe.apply(R)
  output2_g=clahe.apply(G)
  output2_b=clahe.apply(B)
  output_2=cv2.merge((output2_r,output2_g,output2_b))

  output=[img,output_1,output_2]
  titles=['original','after histogram equalisation','clahe']
  # for i in range(3):
  #   plt.subplot(1,3,i+1)
  #   plt.imshow(output[i])
  #   plt.title(titles[i])
  #   plt.xticks([])
  #   plt.yticks([])
  cv2.imwrite('/content/drive/MyDrive/images/histogram_test_new/'+head_tail[1],output_2)
  
  
# read a image using imread
# img = cv2.imread('/content/drive/MyDrive/images/images/apple_1.jpg',1)
# # img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# R,G,B=cv2.split(img)
# output_r=cv2.equalizeHist(R)
# output_g=cv2.equalizeHist(G)
# output_b=cv2.equalizeHist(B)
# output_1=cv2.merge((output_r,output_g,output_b))
# output=[img,output_1]
# titles=['original','after histogram equalisation']
# for i in range(2):
#   plt.subplot(1,2,i+1)
#   plt.imshow(output[i])
#   plt.title(titles[i])
#   plt.xticks([])
#   plt.yticks([])
# cv2.imwrite('/content/drive/MyDrive/images/apple_13.jpg',output_1)

# # creating a Histograms Equalization
# # of a image using cv2.equalizeHist()
# # equ = cv2.equalizeHist(img)
  
# # # stacking images side-by-side
# # res = np.hstack((img, equ))
  
# # # show image input vs output
# # cv2_imshow(res)
  
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# img = cv2.imread('/content/drive/MyDrive/images/images/orange_80.jpg')
# img2=cv2.imread('/content/drive/MyDrive/images/test_histogram_equalisation/orange_80.jpg')
# res = np.hstack((img, img2))
  
# # show image input vs output
# cv2_imshow(res)
  
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# img = cv2.imread('/content/drive/MyDrive/images/apple_1.jpg',0)
# hist1 = cv2.calcHist([img],[0],None,[256],[0,256])
# img_2 = cv2.equalizeHist(img)
# hist2 = cv2.calcHist([img_2],[0],None,[256],[0,256])
# plt.subplot(221),plt.imshow(img);
# plt.subplot(222),plt.plot(hist1);
# plt.subplot(223),plt.imshow(img_2);
# plt.subplot(224),plt.plot(hist2);

# import Opencv
import cv2
import glob
import os
  
# import Numpy
import numpy as np
from google.colab.patches import cv2_imshow
path=glob.glob('/content/drive/MyDrive/images/images/*.jpg')

img = cv2.imread('/content/drive/MyDrive/images/images/banana_35.jpg',1)
# head_tail = os.path.split(i)
# img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
R,G,B=cv2.split(img)
output_r=cv2.equalizeHist(R)
output_g=cv2.equalizeHist(G)
output_b=cv2.equalizeHist(B)


output_1=cv2.merge((output_r,output_g,output_b))
# output_1=cv2.equalizeHist(img)
clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
output2_r=clahe.apply(R)
output2_g=clahe.apply(G)
output2_b=clahe.apply(B)
output_2=cv2.merge((output2_r,output2_g,output2_b))

output=[img,output_1,output_2]
titles=['original','after histogram equalisation','clahe']
for i in range(3):
  plt.subplot(1,3,i+1)
  plt.imshow(output[i])
  plt.title(titles[i])
  plt.xticks([])
  plt.yticks([])
# cv2.imwrite('/content/drive/MyDrive/images/final_histogram_images/'+head_tail[1],output_1)
  
  
# read a image using imread
# img = cv2.imread('/content/drive/MyDrive/images/images/apple_1.jpg',0)
# # img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# R,G,B=cv2.split(img)
# output_r=cv2.equalizeHist(R)
# output_g=cv2.equalizeHist(G)
# output_b=cv2.equalizeHist(B)
# output_1=cv2.merge((output_r,output_g,output_b))
# output=[img,output_1]
# titles=['original','after histogram equalisation']
# for i in range(2):
#   plt.subplot(1,2,i+1)
#   plt.imshow(output[i])
#   plt.title(titles[i])
#   plt.xticks([])
#   plt.yticks([])
cv2.imwrite('/content/drive/MyDrive/images/banana_13.jpg',output_2)

# creating a Histograms Equalization
# of a image using cv2.equalizeHist()
# equ = cv2.equalizeHist(img)
  
# # stacking images side-by-side
# res = np.hstack((img, equ))
  
# # show image input vs output
# cv2_imshow(res)
  
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# True

# %%
#gamma correction
import cv2
import numpy as np
import glob
import os
from google.colab.patches import cv2_imshow


def gammaCorrection(src, gamma):
    invGamma = 1 / gamma

    table = [((i / 255) ** invGamma) * 255 for i in range(256)]
    table = np.array(table, np.uint8)
    return cv2.LUT(src, table)
path=glob.glob('/content/drive/MyDrive/images/images_test/*')
for i in path:
  img = cv2.imread(i,1)
  head_tail = os.path.split(i)
  # print(i)
  gammaImg = gammaCorrection(img,2.4)   #3.2
  # img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  
  # for i in range(3):
  #   plt.subplot(1,3,i+1)
  #   plt.imshow(output[i])
  #   plt.title(titles[i])
  #   plt.xticks([])
  #   plt.yticks([])
  # print(i)
  cv2.imwrite('/content/drive/MyDrive/images/gamma_test_new/'+head_tail[1],gammaImg)


# img = cv2.imread('/content/drive/MyDrive/images/images_train/watch_42.jpg')

# gammaImg = gammaCorrection(img,2.4)



# cv2_imshow( img)

# cv2_imshow(gammaImg)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# %matplotlib inline
from utils import utils
import canny_edge_detector as ced

# %%
# !pwd
# %cd /content/drive/MyDrive/images
# !pwd
# Out:
# /content
# /content/drive/MyDrive/images
# /content/drive/MyDrive/images

# %%
# !unzip /content/drive/MyDrive/images/images.zip -d .
# Out:
# Archive:  /content/drive/MyDrive/images/images.zip
#   inflating: ./images/apple_77.jpg
#   inflating: ./images/apple_78.jpg
#   inflating: ./images/apple_79.jpg
#   inflating: ./images/apple_80.jpg
#   inflating: ./images/apple_81.jpg
#   inflating: ./images/apple_82.jpg
#   inflating: ./images/apple_83.jpg
#   inflating: ./images/apple_84.jpg
#   inflating: ./images/apple_85.jpg
#   inflating: ./images/apple_86.jpg
#   inflating: ./images/apple_87.jpg
#   inflating: ./images/apple_88.jpg
#   inflating: ./images/apple_89.jpg
#   inflating: ./images/apple_90.jpg
#   inflating: ./images/apple_91.jpg
#   inflating: ./images/apple_92.jpg
#   inflating: ./images/apple_93.jpg
#   inflating: ./images/apple_94.jpg
#   inflating: ./images/apple_95.jpg
#   inflating: ./images/banana_77.jpg
#   inflating: ./images/banana_78.jpg
#   inflating: ./images/banana_79.jpg
#   inflating: ./images/banana_80.jpg
#   inflating: ./images/banana_81.jpg
#   inflating: ./images/banana_82.jpg
# ...

# %%
#canny edge detection
import cv2
from google.colab.patches import cv2_imshow
  
img = cv2.imread("/content/drive/MyDrive/images/histogram_equalisation/apple_53.jpg")  # Read image
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  
# Setting parameter values
t_lower = 50  # Lower Threshold
t_upper = 150  # Upper threshold
  
# Applying the Canny Edge filter
edge = cv2.Canny(gray_image, t_lower, t_upper)
  
cv2_imshow(img)
cv2_imshow(gray_image)
cv2_imshow(edge)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x261 at 0x7F761EBEC790>
# <PIL.Image.Image image mode=L size=300x261 at 0x7F761EBEC940>
# <PIL.Image.Image image mode=L size=300x261 at 0x7F75EF2A7250>

# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
  
   
# defining the canny detector function
   
# here weak_th and strong_th are thresholds for
# double thresholding step
def Canny_detector(img, weak_th = None, strong_th = None):
      
    # conversion of image to grayscale
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
       
    # Noise reduction step
    img = cv2.GaussianBlur(img, (5, 5), 1.4)
       
    # Calculating the gradients
    gx = cv2.Sobel(np.float32(img), cv2.CV_64F, 1, 0, 3)
    gy = cv2.Sobel(np.float32(img), cv2.CV_64F, 0, 1, 3)
      
    # Conversion of Cartesian coordinates to polar 
    mag, ang = cv2.cartToPolar(gx, gy, angleInDegrees = True)
       
    # setting the minimum and maximum thresholds 
    # for double thresholding
    mag_max = np.max(mag)
    if not weak_th:weak_th = mag_max * 0.1
    if not strong_th:strong_th = mag_max * 0.5
      
    # getting the dimensions of the input image  
    height, width = img.shape
       
    # Looping through every pixel of the grayscale 
    # image
    for i_x in range(width):
        for i_y in range(height):
               
            grad_ang = ang[i_y, i_x]
            grad_ang = abs(grad_ang-180) if abs(grad_ang)>180 else abs(grad_ang)
               
            # selecting the neighbours of the target pixel
            # according to the gradient direction
            # In the x axis direction
            if grad_ang<= 22.5:
                neighb_1_x, neighb_1_y = i_x-1, i_y
                neighb_2_x, neighb_2_y = i_x + 1, i_y
              
            # top right (diagonal-1) direction
            elif grad_ang>22.5 and grad_ang<=(22.5 + 45):
                neighb_1_x, neighb_1_y = i_x-1, i_y-1
                neighb_2_x, neighb_2_y = i_x + 1, i_y + 1
              
            # In y-axis direction
            elif grad_ang>(22.5 + 45) and grad_ang<=(22.5 + 90):
                neighb_1_x, neighb_1_y = i_x, i_y-1
                neighb_2_x, neighb_2_y = i_x, i_y + 1
              
            # top left (diagonal-2) direction
            elif grad_ang>(22.5 + 90) and grad_ang<=(22.5 + 135):
                neighb_1_x, neighb_1_y = i_x-1, i_y + 1
                neighb_2_x, neighb_2_y = i_x + 1, i_y-1
              
            # Now it restarts the cycle
            elif grad_ang>(22.5 + 135) and grad_ang<=(22.5 + 180):
                neighb_1_x, neighb_1_y = i_x-1, i_y
                neighb_2_x, neighb_2_y = i_x + 1, i_y
               
            # Non-maximum suppression step
            if width>neighb_1_x>= 0 and height>neighb_1_y>= 0:
                if mag[i_y, i_x]<mag[neighb_1_y, neighb_1_x]:
                    mag[i_y, i_x]= 0
                    continue
   
            if width>neighb_2_x>= 0 and height>neighb_2_y>= 0:
                if mag[i_y, i_x]<mag[neighb_2_y, neighb_2_x]:
                    mag[i_y, i_x]= 0
   
    weak_ids = np.zeros_like(img)
    strong_ids = np.zeros_like(img)              
    ids = np.zeros_like(img)
       
    # double thresholding step
    for i_x in range(width):
        for i_y in range(height):
              
            grad_mag = mag[i_y, i_x]
              
            if grad_mag<weak_th:
                mag[i_y, i_x]= 0
            elif strong_th>grad_mag>= weak_th:
                ids[i_y, i_x]= 1
            else:
                ids[i_y, i_x]= 2
       
       
    # finally returning the magnitude of
    # gradients of edges
    return mag
   
frame = cv2.imread("/content/drive/MyDrive/images/histogram_equalisation/apple_53.jpg")
  
# calling the designed function for
# finding edges
canny_img = Canny_detector(frame)
   
# Displaying the input and output image  
plt.figure()
f, plots = plt.subplots(2, 1) 
plots[0].imshow(frame)
plots[1].imshow(canny_img)

# %%
#canny edge detection
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
  
   
# defining the canny detector function
   
# here weak_th and strong_th are thresholds for
# double thresholding step
def Canny_detector(img, weak_th = None, strong_th = None):
      
    # conversion of image to grayscale
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
       
    # Noise reduction step
    img = cv2.GaussianBlur(img, (5, 5), 1.4)
       
    # Calculating the gradients
    gx = cv2.Sobel(np.float32(img), cv2.CV_64F, 1, 0, 3)
    gy = cv2.Sobel(np.float32(img), cv2.CV_64F, 0, 1, 3)
      
    # Conversion of Cartesian coordinates to polar 
    mag, ang = cv2.cartToPolar(gx, gy, angleInDegrees = True)
       
    # setting the minimum and maximum thresholds 
    # for double thresholding
    mag_max = np.max(mag)
    if not weak_th:weak_th = mag_max * 0.1
    if not strong_th:strong_th = mag_max * 0.5
      
    # getting the dimensions of the input image  
    height, width = img.shape
       
    # Looping through every pixel of the grayscale 
    # image
    for i_x in range(width):
        for i_y in range(height):
               
            grad_ang = ang[i_y, i_x]
            grad_ang = abs(grad_ang-180) if abs(grad_ang)>180 else abs(grad_ang)
               
            # selecting the neighbours of the target pixel
            # according to the gradient direction
            # In the x axis direction
            if grad_ang<= 22.5:
                neighb_1_x, neighb_1_y = i_x-1, i_y
                neighb_2_x, neighb_2_y = i_x + 1, i_y
              
            # top right (diagonal-1) direction
            elif grad_ang>22.5 and grad_ang<=(22.5 + 45):
                neighb_1_x, neighb_1_y = i_x-1, i_y-1
                neighb_2_x, neighb_2_y = i_x + 1, i_y + 1
              
            # In y-axis direction
            elif grad_ang>(22.5 + 45) and grad_ang<=(22.5 + 90):
                neighb_1_x, neighb_1_y = i_x, i_y-1
                neighb_2_x, neighb_2_y = i_x, i_y + 1
              
            # top left (diagonal-2) direction
            elif grad_ang>(22.5 + 90) and grad_ang<=(22.5 + 135):
                neighb_1_x, neighb_1_y = i_x-1, i_y + 1
                neighb_2_x, neighb_2_y = i_x + 1, i_y-1
              
            # Now it restarts the cycle
            elif grad_ang>(22.5 + 135) and grad_ang<=(22.5 + 180):
                neighb_1_x, neighb_1_y = i_x-1, i_y
                neighb_2_x, neighb_2_y = i_x + 1, i_y
               
            # Non-maximum suppression step
            if width>neighb_1_x>= 0 and height>neighb_1_y>= 0:
                if mag[i_y, i_x]<mag[neighb_1_y, neighb_1_x]:
                    mag[i_y, i_x]= 0
                    continue
   
            if width>neighb_2_x>= 0 and height>neighb_2_y>= 0:
                if mag[i_y, i_x]<mag[neighb_2_y, neighb_2_x]:
                    mag[i_y, i_x]= 0
   
    weak_ids = np.zeros_like(img)
    strong_ids = np.zeros_like(img)              
    ids = np.zeros_like(img)
       
    # double thresholding step
    for i_x in range(width):
        for i_y in range(height):
              
            grad_mag = mag[i_y, i_x]
              
            if grad_mag<weak_th:
                mag[i_y, i_x]= 0
            elif strong_th>grad_mag>= weak_th:
                ids[i_y, i_x]= 1
            else:
                ids[i_y, i_x]= 2
       
       
    # finally returning the magnitude of
    # gradients of edges
    return mag
# img = cv2.imread('/content/drive/MyDrive/images/apple_1.jpg',0)
# hist1 = cv2.calcHist([img],[0],None,[256],[0,256])
# img_2 = cv2.equalizeHist(img)
# hist2 = cv2.calcHist([img_2],[0],None,[256],[0,256])
# plt.subplot(221),plt.imshow(img);
# plt.subplot(222),plt.plot(hist1);
# plt.subplot(223),plt.imshow(img_2);
# plt.subplot(224),plt.plot(hist2);

# import Opencv
import cv2
import glob
import os
  
# import Numpy
import numpy as np
from google.colab.patches import cv2_imshow
path=glob.glob('/content/drive/MyDrive/images/test_histogram_eqalisation/*')
for i in path:
  img = cv2.imread(i,1)
  head_tail = os.path.split(i)
  # t_lower = 50  # Lower Threshold
  # t_upper = 150  # Upper threshold
  
  # Applying the Canny Edge filter
  edge =Canny_detector(img)
  

  # output=[img,output_1,output_2]
  # titles=['original','after histogram equalisation','clahe']
  # for i in range(3):
  #   plt.subplot(1,3,i+1)
  #   plt.imshow(output[i])
  #   plt.title(titles[i])
  #   plt.xticks([])
  #   plt.yticks([])
  cv2.imwrite('/content/drive/MyDrive/images/canny_edge_test/'+head_tail[1],edge)

# %%
from google.colab import drive
drive.mount('/content/drive')
