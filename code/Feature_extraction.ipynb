# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA
import glob
import os
path=glob.glob('/content/drive/MyDrive/images/train_histogram_equalisation/*')

# %%
import matplotlib.image as mpimg
list_img=[]
for i in path:
  img = plt.imread(i)
  list_img.append(img)
plt.imshow(list_img[0])

# %%
plt.imshow(list_img[1], cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 4567.5, 3044.5, -0.5)

# %%
list_img[0].shape
# Out:
# (1200, 1600, 3)

# %%
avgFace = np.average(list_img, axis=0)
plt.imshow(avgFace, cmap='gray')
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-d58f9f240090> in <cell line: 1>()
# ----> 1 avgFace = np.average(list_img, axis=0)
#       2 plt.imshow(avgFace, cmap='gray')
#       3 plt.axis('off')
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in average(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     493
#     494     if weights is None:
# --> 495         avg = a.mean(axis)
#     496         scl = avg.dtype.type(a.size/avg.size)
#     497     else:
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     177             is_float16_result = True
#     178
# --> 179     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     180     if isinstance(ret, mu.ndarray):
# ...

# %%
# import matplotlib.image as img
# img_mat=img.imread()
import cv2
import pandas as pd

# Convert to Grayscale
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/images/train_histogram_equalisation/apple_19.jpg')
# imageMat_resha = img.reshape(img.shape[0],-1)
# mat_df=pd.DataFrame(img_gray)
arr=np.array(img)
arr=arr.reshape(640,640)
mat_df=pd.DataFrame(arr)
mat_df
# mat_df=pd.DataFrame(arr)
# cv2_imshow(img_gray)
# cv2.waitKey(0)
  
# # Window shown waits for any key pressing event
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-58bedfc612d0> in <cell line: 12>()
#      10 # mat_df=pd.DataFrame(img_gray)
#      11 arr=np.array(img)
# ---> 12 arr=arr.reshape(640,640)
#      13 mat_df=pd.DataFrame(arr)
#      14 mat_df
#
# ValueError: cannot reshape array of size 5760000 into shape (640,640)

# %%
list_img=[]

for i in path:
  img=cv2.imread(i)
  arr=np.array(img)
  arr=arr.reshape(arr.shape[0],-1)
  # arr=list(arr)
  list_img.append(arr)

# %%
list_img=np.array(list_img)
# Out:
# <ipython-input-77-da993b638d24>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   list_img=np.array(list_img)

# %%
# print(list_img.shape[0])

a=[[1,2,3],[2,3,4,5]]
a=np.array(a)
a.shape
# Out:
# <ipython-input-83-a62cac158d3c>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   a=np.array(a)
# (2,)

# %%
from PIL import Image
 
# Opens a image in RGB mode
im = Image.open(r"/content/drive/MyDrive/images/train_histogram_equalisation/apple_19.jpg")
 
# Size of the image in pixels (size of original image)
# (This is not mandatory)
# width, height = im.size
 
# # Setting the points for cropped image
# left = 4
# top = height / 5
# right = 154
# bottom = 3 * height / 5
 
# # Cropped image of above dimension
# # (It will not change original image)
# im1 = im.crop((left, top, right, bottom))
newsize = (640, 640)
im1 = im.resize(newsize)
# img=cv2.imread(im1)
# imageMat_resha = img.reshape(img.shape[0],-1)
# mat_df=pd.DataFrame(img_gray)
arr=np.array(im1)
arr.shape
# arr=arr.reshape(640,640)
# mat_df=pd.DataFrame(arr)
# mat_df
# Shows the image in image viewer
# im1.show()
# Out:
# (640, 640, 3)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import glob
import os
path=glob.glob('/content/drive/MyDrive/images/train_histogram_equalisation/*')

# %%
img=cv2.imread('/content/drive/MyDrive/images/train_histogram_equalisation/bottle_79.jpg')
img.shape[1]
# plt.imshow(img)
# r,g,b=cv2.split(img)
# r,g,b=r/255,g/255,b/255
# plt.imshow(img)
# b.shape
# Out:
# 4032

# %%
# pca_components=int(r.shape[1]/5)
pca_components=50
print(pca_components)
pca_r=PCA(n_components=pca_components)
reduced_r=pca_r.fit_transform(r)
pca_g=PCA(n_components=pca_components)
reduced_g=pca_g.fit_transform(g)
pca_b=PCA(n_components=pca_components)
reduced_b=pca_b.fit_transform(b)
reduced_g.shape
# Out:
# 50
# (3024, 50)

# %%
combined=np.array([reduced_r,reduced_g,reduced_b])
combined.shape
reconstructed_r=pca_r.inverse_transform(reduced_r)
reconstructed_g=pca_g.inverse_transform(reduced_g)
reconstructed_b=pca_b.inverse_transform(reduced_b)
reconstructed_r.shape
plt.imshow(reconstructed_r)

# %%
img_reconstructed=(cv2.merge((reconstructed_r,reconstructed_g,reconstructed_b)))
plt.imshow(img_reconstructed)
# img_reconstructed.shape()
# cv2_imshow(img_reconstructed*255)
# plt.savefig('/content/drive/MyDrive/images/bottle_plt_79.jpg')
cv2.imwrite(r'/content/drive/MyDrive/images/bottle_low_79.jpg', 255*img_reconstructed)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# True

# %%
img=cv2.imread('/content/drive/MyDrive/images/bottle_modified_79.jpg')
img.shape
# Out:
# (3024, 4032, 3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import glob
import os
path=glob.glob('/content/drive/MyDrive/images/train_histogram_equalisation/*')

# %%
for i in path:
  img=cv2.imread(i)
  img.shape
  plt.imshow(img)
  head_tail = os.path.split(i)
  r,g,b=cv2.split(img)
  r,g,b=r/255,g/255,b/255
  pca_components=int(r.shape[1]/5)
  print(r.shape)
  pca_r=PCA(n_components=pca_components)
  reduced_r=pca_r.fit_transform(r)
  pca_g=PCA(n_components=pca_components)
  reduced_g=pca_g.fit_transform(g)
  pca_b=PCA(n_components=pca_components)
  reduced_b=pca_b.fit_transform(b)
  combined=np.array([reduced_r,reduced_g,reduced_b])
  combined.shape
  reconstructed_r=pca_r.inverse_transform(reduced_r)
  reconstructed_g=pca_g.inverse_transform(reduced_g)
  reconstructed_b=pca_b.inverse_transform(reduced_b)
  img_reconstructed=(cv2.merge((reconstructed_r,reconstructed_g,reconstructed_b)))
  cv2.imwrite('/content/drive/MyDrive/images/pca_extraction_train/'+head_tail[1], 255*img_reconstructed)  
  # plt.axis('off')
  # plt.imshow(img_reconstructed)
  # plt.savefig('/content/drive/MyDrive/images/pca_extraction_train/'+head_tail[1])
  # plt.imshow(g)
# Out:
# (1200, 1600)
# (3045, 4568)
# (800, 700)
# (800, 800)
# (1046, 1400)
# (640, 960)
# (458, 610)
# (300, 333)
# (436, 652)
# (3024, 4032)
# (428, 450)
# (1500, 1500)
# (349, 349)
# (500, 500)
# (250, 250)
# (500, 500)
# (368, 654)
# (220, 220)
# (250, 196)
# (1010, 1010)
# (1332, 1300)
# (600, 800)
# (600, 800)
# (476, 634)
# (340, 490)
# (587, 950)
# (645, 645)
# (500, 500)
# (720, 1280)
# (640, 640)
# (1135, 1600)
# (810, 720)
# (533, 800)
# (900, 1200)
# (295, 260)
# (232, 350)
# (936, 1023)
# (261, 300)
# (640, 960)
# (300, 271)
# (227, 300)
# (450, 468)
# (350, 620)
# (1360, 2040)
# (641, 960)
# (452, 602)
# (600, 800)
# (335, 337)
# (720, 720)
# (500, 500)
# (240, 351)
# (287, 338)
# (2000, 2000)
# (387, 620)
# (768, 1366)
# (1600, 1522)
# (1390, 1300)
# (352, 389)
# (450, 298)
# (439, 780)
# (171, 166)
# (947, 1320)
# (797, 800)
# (1440, 1080)
# (250, 250)
# (800, 800)
# (708, 1000)
# (300, 300)
# (241, 350)
# (350, 700)
# (3332, 4998)
# (241, 350)
# (1696, 1132)
# (693, 693)
# ...

# %%
  from PIL import Image 
  import PIL
  img=cv2.imread('/content/drive/MyDrive/images/train_histogram_equalisation/apple_17.jpg')
  img.shape
  # plt.imshow(img)
  head_tail = os.path.split('/content/drive/MyDrive/images/train_histogram_equalisation/apple_17.jpg')
  r,g,b=cv2.split(img)
  r,g,b=r/255,g/255,b/255
  pca_components=100
  # print(r.shape)
  pca_r=PCA(n_components=pca_components)
  reduced_r=pca_r.fit_transform(r)
  pca_g=PCA(n_components=pca_components)
  reduced_g=pca_g.fit_transform(g)
  pca_b=PCA(n_components=pca_components)
  reduced_b=pca_b.fit_transform(b)
  combined=np.array([reduced_r,reduced_g,reduced_b])
  combined.shape
  reconstructed_r=pca_r.inverse_transform(reduced_r)
  reconstructed_g=pca_g.inverse_transform(reduced_g)
  reconstructed_b=pca_b.inverse_transform(reduced_b)
  img_reconstructed=(cv2.merge((reconstructed_r,reconstructed_g,reconstructed_b)))
  cv2_imshow(img_reconstructed)
  # plt.axis('off')
  # # plt.imshow(img)
  # # cv2_imshow(img_reconstructed)
  # plt.savefig('/content/drive/MyDrive/images/'+head_tail[1])
  # plt.imshow(g)
  # cv2.imwrite('/content/drive/MyDrive/images/'+head_tail[1],img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x800 at 0x7F66FA871490>
